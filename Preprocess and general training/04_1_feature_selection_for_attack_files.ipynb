# %%
##  "attacks" folder (with attack csv files) is required for the operation of the program.
##  "attacks" folder must be located in the same directory as the program.


##  the purpose of this code is to determine which features to use in the machine learning phase.
##  for this purpose, the importance weights of the attacks are calculated.
##  this calculation was made using sklearn-RandomForestRegressor.

##  the some codes parts used for calculation and graphing are taken from the following site.
##  http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")
        

# CSV files names:
csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# Headers of column
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")
for j in csv_files:
    df=pd.read_csv(".\\attacks\\"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    #plt.savefig("./feaure_pics/"+j[0:-4]+".pdf")
    #plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', papertype = 'a4', orientation = 'portrait', format = 'pdf')
    #plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",dpi='figure',format='pdf',metadata='pdf',bbox_inches='tight',pad_inches=0.1,facecolor='auto',
    #           edgecolor='auto',backend=None)
    plt.savefig("./feaure_pics/"+j[0:-4]+".pdf", format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1, orientation='portrait', edgecolor='w', facecolor='w')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.348892
# Flow IAT Max                   0.015856
# Flow Duration                  0.013964
# Flow IAT Mean                  0.007480
# Flow IAT Min                   0.006555
# Flow Bytes/s                   0.004899
# Flow IAT Std                   0.004805
# Flow Packets/s                 0.000734
# Fwd IAT Total                  0.000403
# Fwd Packet Length Mean         0.000204
# Total Backward Packets         0.000179
# Total Length of Bwd Packets    0.000093
# Total Length of Fwd Packets    0.000065
# Total Fwd Packets              0.000064
# Bwd Packet Length Std          0.000055
# Bwd Packet Length Max          0.000036
# Fwd Packet Length Max          0.000034
# Bwd Packet Length Min          0.000033
# Fwd Packet Length Min          0.000033
# Fwd Packet Length Std          0.000014
#
#
#
# Bot=["Bwd Packet Length Mean","Flow IAT Max","Flow Duration","Flow IAT Mean","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Fwd Packet Length Max          0.605994
# Total Length of Fwd Packets    0.200895
# Bwd Packet Length Min          0.000788
# Flow IAT Min                   0.000180
# Flow IAT Mean                  0.000069
# Bwd Packet Length Mean         0.000062
# Flow Duration                  0.000051
# Total Backward Packets         0.000049
# Flow IAT Max                   0.000047
# Flow Bytes/s                   0.000045
# Fwd IAT Total                  0.000033
# Flow IAT Std                   0.000030
# Flow Packets/s                 0.000025
# Fwd Packet Length Std          0.000019
# Fwd Packet Length Mean         0.000015
# Bwd Packet Length Max          0.000012
# Total Length of Bwd Packets    0.000010
# Fwd Packet Length Min          0.000005
# Bwd Packet Length Std          0.000003
# Total Fwd Packets              0.000002
#
#
#
# DDoS=["Fwd Packet Length Max","Total Length of Fwd Packets","Bwd Packet Length Min","Flow IAT Min","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Bwd Packet Length Std          0.581824
# Flow IAT Min                   0.148608
# Fwd Packet Length Min          0.026394
# Flow IAT Mean                  0.021005
# Total Backward Packets         0.008279
# Flow IAT Std                   0.003555
# Flow IAT Max                   0.000870
# Fwd IAT Total                  0.000746
# Flow Duration                  0.000696
# Flow Packets/s                 0.000608
# Flow Bytes/s                   0.000282
# Fwd Packet Length Max          0.000143
# Bwd Packet Length Mean         0.000142
# Total Length of Fwd Packets    0.000117
# Fwd Packet Length Mean         0.000073
# Total Fwd Packets              0.000031
# Total Length of Bwd Packets    0.000028
# Bwd Packet Length Max          0.000017
# Bwd Packet Length Min          0.000016
# Fwd Packet Length Std          0.000008
#
#
#
# DoS GoldenEye=["Bwd Packet Length Std","Flow IAT Min","Fwd Packet Length Min","Flow IAT Mean","Total Backward Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                                 importance
# Features
# Bwd Packet Length Std        5.851354e-01
# Flow Duration                1.652924e-03
# Flow IAT Min                 1.638107e-03
# Total Backward Packets       4.013575e-04
# Total Length of Bwd Packets  3.920825e-04
# Flow IAT Std                 3.293101e-04
# Fwd IAT Total                1.803934e-04
# Flow IAT Mean                1.410828e-04
# Flow IAT Max                 1.001071e-04
# Flow Packets/s               8.752145e-05
# Total Fwd Packets            4.443363e-05
# Flow Bytes/s                 1.655175e-05
# Bwd Packet Length Max        1.632388e-05
# Bwd Packet Length Mean       1.288989e-05
# Bwd Packet Length Min        8.493458e-06
# Fwd Packet Length Max        6.718336e-06
# Fwd Packet Length Mean       4.550836e-06
# Fwd Packet Length Std        4.276556e-06
# Total Length of Fwd Packets  2.727893e-06
# Fwd Packet Length Min        1.851660e-07
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Flow Duration","Flow IAT Min","Total Backward Packets","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow IAT Mean                  0.661660
# Fwd Packet Length Min          0.111954
# Bwd Packet Length Std          0.043655
# Bwd Packet Length Mean         0.029701
# Total Length of Bwd Packets    0.008723
# Bwd Packet Length Max          0.004246
# Flow IAT Min                   0.002505
# Total Fwd Packets              0.001191
# Flow IAT Std                   0.000576
# Fwd Packet Length Mean         0.000575
# Bwd Packet Length Min          0.000570
# Fwd Packet Length Std          0.000481
# Total Length of Fwd Packets    0.000453
# Fwd Packet Length Max          0.000378
# Flow Duration                  0.000271
# Flow IAT Max                   0.000239
# Fwd IAT Total                  0.000230
# Flow Bytes/s                   0.000186
# Total Backward Packets         0.000138
# Flow Packets/s                 0.000069
#
#
#
# DoS Slowhttptest=["Flow IAT Mean","Fwd Packet Length Min","Bwd Packet Length Std","Bwd Packet Length Mean","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                                 importance
# Features
# Flow IAT Mean                4.757599e-01
# Bwd Packet Length Mean       7.545010e-02
# Total Fwd Packets            2.384609e-02
# Total Length of Bwd Packets  2.201916e-02
# Bwd Packet Length Std        6.954165e-03
# Flow IAT Min                 1.225209e-03
# Bwd Packet Length Max        1.005304e-03
# Flow Bytes/s                 8.980458e-04
# Fwd Packet Length Max        7.526391e-04
# Total Backward Packets       7.229543e-04
# Fwd IAT Total                6.088984e-04
# Fwd Packet Length Std        5.750445e-04
# Total Length of Fwd Packets  5.413825e-04
# Fwd Packet Length Mean       4.925360e-04
# Flow IAT Max                 4.272934e-04
# Flow Duration                3.781640e-04
# Flow IAT Std                 2.973059e-04
# Flow Packets/s               1.823937e-04
# Fwd Packet Length Min        1.981146e-05
# Bwd Packet Length Min        5.895039e-07
#
#
#
# DoS slowloris=["Flow IAT Mean","Bwd Packet Length Mean","Total Fwd Packets","Total Length of Bwd Packets","Bwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.093712
# Fwd Packet Length Std          0.022084
# Fwd Packet Length Mean         0.020957
# Bwd Packet Length Mean         0.000758
# Total Length of Bwd Packets    0.000402
# Flow Duration                  0.000175
# Bwd Packet Length Max          0.000172
# Flow IAT Min                   0.000160
# Bwd Packet Length Std          0.000121
# Total Length of Fwd Packets    0.000097
# Flow IAT Max                   0.000096
# Fwd IAT Total                  0.000081
# Total Backward Packets         0.000074
# Fwd Packet Length Min          0.000062
# Flow IAT Mean                  0.000055
# Total Fwd Packets              0.000047
# Flow Packets/s                 0.000045
# Flow IAT Std                   0.000041
# Flow Bytes/s                   0.000021
# Bwd Packet Length Min          0.000001
#
#
#
# FTP-Patator=["Fwd Packet Length Max","Fwd Packet Length Std","Fwd Packet Length Mean","Bwd Packet Length Mean","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Total Backward Packets            0.056
# Bwd Packet Length Mean            0.056
# Bwd Packet Length Max             0.052
# Total Length of Bwd Packets       0.052
# Total Fwd Packets                 0.036
# Bwd Packet Length Std             0.032
# Flow Duration                     0.028
# Fwd IAT Total                     0.020
# Total Length of Fwd Packets       0.016
# Fwd Packet Length Max             0.008
# Flow IAT Min                      0.008
# Fwd Packet Length Std             0.000
# Fwd Packet Length Mean            0.000
# Fwd Packet Length Min             0.000
# Flow Bytes/s                      0.000
# Flow Packets/s                    0.000
# Flow IAT Mean                     0.000
# Flow IAT Std                      0.000
# Flow IAT Max                      0.000
# Bwd Packet Length Min             0.000
#
#
#
# Heartbleed=["Total Backward Packets","Bwd Packet Length Mean","Bwd Packet Length Max","Total Length of Bwd Packets","Total Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Total Length of Fwd Packets    0.151320
# Fwd Packet Length Mean         0.124665
# Fwd Packet Length Max          0.044881
# Flow Duration                  0.032812
# Flow IAT Max                   0.029552
# Flow IAT Std                   0.015564
# Flow IAT Min                   0.009895
# Bwd Packet Length Std          0.006715
# Total Backward Packets         0.006545
# Flow Bytes/s                   0.005607
# Bwd Packet Length Max          0.005408
# Fwd IAT Total                  0.004438
# Bwd Packet Length Min          0.004300
# Flow IAT Mean                  0.004256
# Fwd Packet Length Std          0.003477
# Flow Packets/s                 0.002318
# Total Fwd Packets              0.002122
# Bwd Packet Length Mean         0.001717
# Total Length of Bwd Packets    0.001452
# Fwd Packet Length Min          0.001082
#
#
#
# Infiltration=["Total Length of Fwd Packets","Fwd Packet Length Mean","Fwd Packet Length Max","Flow Duration","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                               importance
# Features
# Flow Bytes/s                   0.314988
# Total Length of Fwd Packets    0.303646
# Bwd Packet Length Std          0.000349
# Flow IAT Mean                  0.000227
# Flow IAT Max                   0.000202
# Flow Duration                  0.000192
# Fwd Packet Length Max          0.000075
# Bwd Packet Length Min          0.000048
# Fwd Packet Length Std          0.000048
# Fwd IAT Total                  0.000047
# Bwd Packet Length Mean         0.000040
# Total Length of Bwd Packets    0.000039
# Bwd Packet Length Max          0.000036
# Total Fwd Packets              0.000036
# Fwd Packet Length Mean         0.000033
# Flow Packets/s                 0.000027
# Total Backward Packets         0.000017
# Flow IAT Min                   0.000011
# Flow IAT Std                   0.000008
# Fwd Packet Length Min          0.000001
#
#
#
# PortScan=["Flow Bytes/s","Total Length of Fwd Packets","Bwd Packet Length Std","Flow IAT Mean","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Flow IAT Mean                  0.000870
# Fwd Packet Length Max          0.000858
# Flow Duration                  0.000578
# Flow IAT Max                   0.000464
# Total Length of Fwd Packets    0.000441
# Flow IAT Std                   0.000374
# Fwd IAT Total                  0.000299
# Flow Packets/s                 0.000289
# Flow IAT Min                   0.000153
# Flow Bytes/s                   0.000143
# Fwd Packet Length Mean         0.000135
# Total Backward Packets         0.000076
# Fwd Packet Length Std          0.000073
# Total Fwd Packets              0.000063
# Total Length of Bwd Packets    0.000061
# Fwd Packet Length Min          0.000035
# Bwd Packet Length Max          0.000030
# Bwd Packet Length Mean         0.000030
# Bwd Packet Length Std          0.000012
# Bwd Packet Length Min          0.000003
#
#
#
# SSH-Patator=["Flow IAT Mean","Fwd Packet Length Max","Flow Duration","Flow IAT Max","Total Length of Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Total Length of Fwd Packets    0.020415
# Bwd Packet Length Std          0.004772
# Bwd Packet Length Max          0.002277
# Flow Bytes/s                   0.001793
# Fwd Packet Length Std          0.001286
# Flow IAT Max                   0.001242
# Fwd Packet Length Mean         0.001150
# Flow IAT Min                   0.000871
# Fwd IAT Total                  0.000779
# Fwd Packet Length Max          0.000682
# Flow Packets/s                 0.000668
# Flow IAT Mean                  0.000541
# Flow Duration                  0.000515
# Total Fwd Packets              0.000372
# Flow IAT Std                   0.000191
# Bwd Packet Length Mean         0.000154
# Total Backward Packets         0.000139
# Total Length of Bwd Packets    0.000068
# Bwd Packet Length Min          0.000005
# Fwd Packet Length Min          0.000005
#
#
#
# Web Attack=["Total Length of Fwd Packets","Bwd Packet Length Std","Bwd Packet Length Max","Flow Bytes/s","Fwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  10124.832053661346 seconds
